# %% [markdown]
# <a href="https://colab.research.google.com/github/wellingtonvieira001/Comunidade_SST/blob/main/Analise_ENEM_2019.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib as mtl
import numpy as np
import seaborn as sns

# %%
from google.colab import files
df = files.upload()
# Out:
#      <input type="file" id="files-51b95fa1-b81d-4e83-975f-8e1d8468b8b9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-51b95fa1-b81d-4e83-975f-8e1d8468b8b9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# prompt: leia o arquivo anteriormente baixado Dataset_ENEM_2019 (2).csv; esta dando erro analise

df = pd.read_csv('Dataset_ENEM_2019.csv', encoding='latin-1')
df.shape
# Out:
# (909194, 18)

# %%
# prompt: verificar celulas nulas

df.isnull().sum()
# Out:
# NOTA_CN               0
# NOTA_CH               0
# NOTA_LC               0
# NOTA_MT               0
# NOTA_REDACAO          0
# NOTA_MEDIA            0
# TP_ESCOLA             0
# IDADE                 0
# SEXO                  0
# ESTADO_CIVIL          0
# COR_RACA              0
# TP_ENSINO             0
# TREINEIRO             0
# UF_ESC                0
# ESTUDO_PAI            0
# ESTUDO_MAE            0
# PESSOAS_RESIDENCIA    0
# RENDA_MENSAL          0
# dtype: int64

# %%
# prompt: conte where TREINEIRO = 1

df.loc[df['TREINEIRO'] == 1]
# Out:
# Empty DataFrame
# Columns: [NOTA_CN, NOTA_CH, NOTA_LC, NOTA_MT, NOTA_REDACAO, NOTA_MEDIA, TP_ESCOLA, IDADE, SEXO, ESTADO_CIVIL, COR_RACA, TP_ENSINO, TREINEIRO, UF_ESC, ESTUDO_PAI, ESTUDO_MAE, PESSOAS_RESIDENCIA, RENDA_MENSAL]
# Index: []

# %%
df.head()
# Out:
#    NOTA_CN  NOTA_CH  NOTA_LC  NOTA_MT  NOTA_REDACAO  NOTA_MEDIA TP_ESCOLA  \
# 0    574.2    538.7    582.6    571.5         640.0     566.750   Privada
# 1    369.7    398.2    395.6    473.8         480.0     409.325   Pública
# 2    423.0    372.8    488.7    516.5         540.0     450.250   Pública
# 3    412.5    417.2    485.1    446.2         580.0     440.250   Pública
# 4    460.7    570.5    541.8    631.3         640.0     551.075   Pública
#
#    IDADE SEXO  ESTADO_CIVIL  COR_RACA  TP_ENSINO  TREINEIRO UF_ESC ESTUDO_PAI  \
# 0     18    F             1         1        1.0          0     PA          H
# 1     26    F             0         3        1.0          0     PA          B
# 2     17    F             1         3        1.0          0     PA          E
# 3     18    F             1         3        1.0          0     PA          E
# 4     17    M             1         3        1.0          0     PA          D
#
#   ESTUDO_MAE  PESSOAS_RESIDENCIA RENDA_MENSAL
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(_df_27['ESTUDO_MAE'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(_df_27, x='NOTA_CN', y='ESTUDO_MAE', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_6.groupby('ESTUDO_PAI').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# prompt: plot um grafico mostrando NOTA_MEDIA exclua notas aima de 700 e abaixo de 300

df = df[df['NOTA_MEDIA'] > 300]
df = df[df['NOTA_MEDIA'] < 700]

sns.distplot(df['NOTA_MEDIA'])
plt.show()
# Out:
# <ipython-input-30-663c9ab7f37b>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['NOTA_MEDIA'])

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['ESTUDO_PAI'].value_counts()
    for x_label, grp in _df_21.groupby('SEXO')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('SEXO')
_ = plt.ylabel('ESTUDO_PAI')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_4.groupby('TP_ESCOLA').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(_df_26['ESTUDO_PAI'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(_df_26, x='NOTA_CN', y='ESTUDO_PAI', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)

# %%
# prompt: modifique este codigo e gere o mesmo grafico com 'ESTUDO_PAI'

figsize = (12, 1.2 * len(_df_26['ESTUDO_MAE'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(_df_26, x='NOTA_CN', y='ESTUDO_MAE', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)

# %%
from matplotlib import pyplot as plt
_df_0['NOTA_CN'].plot(kind='hist', bins=20, title='NOTA_CN')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# prompt: associe a coluna RENDA_MENSAL com a coluna NOTA_MEDIA,

df.groupby(['RENDA_MENSAL'])['NOTA_MEDIA'].mean()
# Out:
# RENDA_MENSAL
# A    462.863260
# B    471.859179
# C    491.211877
# D    510.912717
# E    513.858867
# F    530.444416
# G    533.588263
# H    551.430411
# I    555.312649
# J    568.492933
# K    569.941858
# L    582.588956
# M    583.568306
# N    595.578624
# O    604.497711
# P    614.495282
# Q    626.421974
# Name: NOTA_MEDIA, dtype: float64

# %%
# prompt: plot um grafico com as variáveis da celula anterior

df.groupby(['RENDA_MENSAL'])['NOTA_MEDIA'].mean().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# Out:
# <Axes: ylabel='RENDA_MENSAL'>

# %%
# prompt: Plot um grafico de renda por escola

df.groupby(['TP_ESCOLA'])['NOTA_MEDIA'].mean().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# Out:
# <Axes: ylabel='TP_ESCOLA'>

# %%
# prompt: GERE GRAFICO COM A MEID DA COLUNA RENDA_MENSAL POR TP_ESCOLA E ORDENE POR TP_ESCOLA

df.groupby(['TP_ESCOLA'])['NOTA_MEDIA'].mean().sort_values(ascending=True).plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# Out:
# <Axes: ylabel='TP_ESCOLA'>

# %%
# prompt: GERE GRAFICO COM UF_ESC E NOTA_MEDIA

df.groupby(['UF_ESC'])['NOTA_MEDIA'].mean().sort_values(ascending=True).plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# Out:
# <Axes: ylabel='UF_ESC'>

# %%
# prompt: GERE GRAFICO COM NOTA_MEDIA E COR_RACA

df.groupby(['COR_RACA'])['NOTA_MEDIA'].mean().sort_values(ascending=True).plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# Out:
# <Axes: ylabel='COR_RACA'>

# %%
# prompt: CRIE GRAFICO COR_RACA e TP_ESCOLA E ORDENE POR COR_RACA

df.groupby(['COR_RACA', 'TP_ESCOLA'])['NOTA_MEDIA'].mean().sort_values(ascending=True).plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# Out:
# <Axes: ylabel='COR_RACA,TP_ESCOLA'>

# %%
# prompt: gere grafico com a media da variavel  PESSOAS_RESIDENCIA

df.groupby(['PESSOAS_RESIDENCIA'])['NOTA_MEDIA'].mean().sort_values(ascending=True).plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# Out:
# <Axes: ylabel='PESSOAS_RESIDENCIA'>

# %%
# prompt: GERE GRAFICO DE COR_RACA E SEXO OREDENE PORCOR_RACA

df.groupby(['COR_RACA', 'SEXO'])['NOTA_MEDIA'].mean().sort_values(ascending=True).plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# Out:
# <Axes: ylabel='COR_RACA,SEXO'>
